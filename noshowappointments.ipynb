# %% [markdown]
# # Импорт библиотек

# %%
import pandas as pd 

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Загрузка данных

# %%
df = pd.read_csv('data/KaggleV2-May-2016.csv')

# %% [markdown]
# # Разведочный анализ данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %% [markdown]
# ## Анализ целевой переменной

# %% [markdown]
# *Каково соотношение людей, которые пропускают приемы, к тем, кто этого не делает?*

# %%
plt.figure(figsize=(8,4))
df['No-show'].hist()
plt.title('Соотношение людей, которые пропускают приемы, к тем, кто этого не делает');

# %%
df['No-show'].value_counts(True)
# Out:
# No     0.798067
# Yes    0.201933
# Name: No-show, dtype: float64

# %% [markdown]
# *Кто не появляется чаще — мужчины или женщины?*

# %%
df[df['No-show']=='Yes']['Gender'].value_counts(True)
# Out:
# F    0.653882
# M    0.346118
# Name: Gender, dtype: float64

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# **Кодировка категориальных признаков**

# %%
categorical_columns_names = ['Gender', 'Neighbourhood']

# %%
encoded_columns = pd.get_dummies(df, columns = categorical_columns_names)

# %% [markdown]
# **Обработка пропусков в данных**

# %%
df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %% [markdown]
# Нам повезло — в нашем наборе данных нет нулевых значений.

# %%
import logging
logging.debug('This is a debug message')
logging.info('This is an informational message')
logging.warning('This message is a warning')
logging.error('This is an error message')
logging.critical('This is a critical message')
# Out:
# WARNING:root:This message is a warning
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %%
from importlib import reload
import logging
reload(logging)
logging.basicConfig(level=logging.DEBUG)

# %%
logging.debug('This is a debug message')
logging.info('This is an informational message')
logging.warning('This message is a warning')
logging.error('This is an error message')
logging.critical('This is a critical message')
# Out:
# DEBUG:root:This is a debug message
# INFO:root:This is an informational message
# WARNING:root:This message is a warning
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %%
logging.FileHandler('data/log_file.log')
# Out:
# <FileHandler c:\Python\win-pc\data\log_file.log (NOTSET)>

# %%
from importlib import reload
import logging
reload(logging)
 
logging.basicConfig(
    format="%(levelname)s: %(asctime)s: %(message)s",
    level=logging.DEBUG
)
logging.info('Check')
# Out:
# INFO: 2023-05-17 17:55:47,580: Check

# %%
import os.path

# Функция для создания лог-файла и записи в него информации
def get_logger(path, file):
  """[Создает лог-файл для логирования в него]
  Аргументы:
      path {string} -- путь к директории
      file {string} -- имя файла
   Возвращает:
      [obj] -- [логер]
  """
  # проверяем, существует ли файл
  log_file = os.path.join(path, file)
 
  #если  файла нет, создаем его
  if not os.path.isfile(log_file):
      open(log_file, "w+").close()
  
  # поменяем формат логирования
  file_logging_format = "%(levelname)s: %(asctime)s: %(message)s"
  
  # конфигурируем лог-файл
  logging.basicConfig(level=logging.INFO, 
  format = file_logging_format)
  logger = logging.getLogger()
  
  # создадим хэнлдер для записи лога в файл
  handler = logging.FileHandler(log_file)
  
  # установим уровень логирования
  handler.setLevel(logging.INFO)
  
  # создадим формат логирования, используя file_logging_format
  formatter = logging.Formatter(file_logging_format)
  handler.setFormatter(formatter)
  
  # добавим хэндлер лог-файлу
  logger.addHandler(handler)
  return logger

# %%
logger = get_logger(path="logs/", file="data.logs")

logger.info("Data")

logger.info("Data shape {}".format(df.shape))

logger.info("Percentage of women: {}".format(df[df['No-show']=='Yes']['Gender'].value_counts(True)[0]))

logger.info("Percentage of men: {}".format(df[df['No-show']=='Yes']['Gender'].value_counts(True)[1]))
# Out:
# INFO: 2023-05-17 17:58:46,427: Data
# INFO: 2023-05-17 17:58:46,429: Data shape (110527, 14)
# INFO: 2023-05-17 17:58:46,451: Percentage of women: 0.653882342398853
# INFO: 2023-05-17 17:58:46,467: Percentage of men: 0.346117657601147

# %%
if df.shape != (110526,14):
 logger.error('Data shape is incorrect!')
# Out:
# ERROR: 2023-05-17 17:59:27,424: Data shape is incorrect!

# %%
from comet_ml import Experiment

# Создайте эксперимент с помощью вашего API ключа
experiment = Experiment(
    api_key="yiFKZg3wKteliE7s4MuSmYcCm",
    project_name="medical-appointment",
    workspace="bulatpython",
    )
# Out:
# DEBUG: 2023-05-17 18:07:08,021: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,029: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,029: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,029: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,029: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,029: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,029: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,029: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,029: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,037: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,037: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,037: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,037: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,037: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,037: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,037: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,037: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,037: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,037: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,037: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,037: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,037: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,037: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,037: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,037: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,037: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,037: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,045: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,045: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,045: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,045: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,045: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,045: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,045: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,045: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,045: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,045: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,045: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,045: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,045: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,045: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,053: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,053: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,053: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,053: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,053: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,053: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,053: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,063: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,063: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,063: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,063: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,063: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,063: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,149: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,149: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,149: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,149: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,149: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,149: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,149: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,149: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,149: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,166: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,166: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,166: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,166: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,166: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,166: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,166: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,166: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,166: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,174: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,174: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,174: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,174: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,174: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,174: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,174: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,174: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,174: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,174: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,182: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,182: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,182: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,182: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,182: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,182: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,182: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,182: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,190: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,190: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,190: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,198: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,198: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,198: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,198: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,198: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,198: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,198: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,198: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,198: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,206: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,206: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,206: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,206: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,206: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,206: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,206: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,214: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,214: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,214: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,214: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,214: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,214: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,214: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,214: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,214: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,214: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,214: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,222: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,222: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,222: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,222: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,222: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,222: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,222: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,222: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,222: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,222: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,222: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,222: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,222: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,222: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,230: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,230: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,230: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,230: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,230: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,230: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,230: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,230: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,230: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,230: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,238: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,238: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,238: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,238: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,238: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,238: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,246: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,246: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,246: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,246: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,246: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,246: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,246: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,246: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,246: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,254: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,254: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,254: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,254: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,254: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,254: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,254: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,254: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,254: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,254: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,254: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,254: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,254: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,254: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,254: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,262: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,262: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,263: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,263: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,263: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,263: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,263: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,263: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,263: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,263: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,263: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,263: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,263: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,263: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,263: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,263: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,270: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,270: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,270: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,270: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,270: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,270: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,270: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,270: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,270: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,270: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,270: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,270: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,270: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,270: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,270: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,270: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,278: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,278: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,278: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,278: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,278: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,278: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,278: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,278: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,278: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,278: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,286: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,286: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,286: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,286: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,294: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,294: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,294: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,294: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,294: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,294: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,294: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,294: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,294: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,294: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,294: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,294: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,294: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,294: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,294: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,302: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,302: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,302: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,302: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,302: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,302: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,302: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,302: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,302: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,302: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,302: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,302: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,302: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,302: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,302: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,302: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,310: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,310: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,310: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,310: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,310: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,310: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,310: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,310: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,310: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,310: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,310: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,310: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,310: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,310: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,310: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,310: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,318: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,318: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,318: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,318: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,318: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,318: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,318: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,318: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,318: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,318: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,318: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,318: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,318: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,318: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,318: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,326: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,326: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,326: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,326: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,326: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,326: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,326: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,326: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,326: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,334: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,334: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,334: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,334: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,334: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,334: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,334: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,334: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,334: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,342: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,342: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,342: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,342: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,342: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,342: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,342: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,342: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,350: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,350: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,352: Looking up key: disable_auto_logging, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,352: Searching <ConfigOSEnv> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,352: Searching <ConfigEnvFileEnv: None> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,352: Searching <ConfigDictEnv: {}> for COMET_DISABLE_AUTO_LOGGING
# DEBUG: 2023-05-17 18:07:08,352: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,352: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,352: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,352: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,352: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,356: Looking up key: console, namespace: ['comet', 'logging']
# DEBUG: 2023-05-17 18:07:08,356: Searching <ConfigOSEnv> for COMET_LOGGING_CONSOLE
# DEBUG: 2023-05-17 18:07:08,356: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_CONSOLE
# DEBUG: 2023-05-17 18:07:08,356: Searching <ConfigDictEnv: {}> for COMET_LOGGING_CONSOLE
# DEBUG: 2023-05-17 18:07:08,356: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,358: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,358: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,358: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,358: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,361: Looking up key: rich_output, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,361: Searching <ConfigOSEnv> for COMET_RICH_OUTPUT
# DEBUG: 2023-05-17 18:07:08,361: Searching <ConfigEnvFileEnv: None> for COMET_RICH_OUTPUT
# DEBUG: 2023-05-17 18:07:08,361: Searching <ConfigDictEnv: {}> for COMET_RICH_OUTPUT
# DEBUG: 2023-05-17 18:07:08,361: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,363: Looking up key: file, namespace: ['comet', 'logging']
# DEBUG: 2023-05-17 18:07:08,363: Searching <ConfigOSEnv> for COMET_LOGGING_FILE
# DEBUG: 2023-05-17 18:07:08,363: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_FILE
# DEBUG: 2023-05-17 18:07:08,363: Searching <ConfigDictEnv: {}> for COMET_LOGGING_FILE
# DEBUG: 2023-05-17 18:07:08,365: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,365: Looking up key: project_name, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,365: Searching <ConfigOSEnv> for COMET_PROJECT_NAME
# DEBUG: 2023-05-17 18:07:08,365: Searching <ConfigEnvFileEnv: None> for COMET_PROJECT_NAME
# DEBUG: 2023-05-17 18:07:08,366: Searching <ConfigDictEnv: {}> for COMET_PROJECT_NAME
# DEBUG: 2023-05-17 18:07:08,366: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,366: Looking up key: file_level, namespace: ['comet', 'logging']
# DEBUG: 2023-05-17 18:07:08,366: Searching <ConfigOSEnv> for COMET_LOGGING_FILE_LEVEL
# DEBUG: 2023-05-17 18:07:08,366: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_FILE_LEVEL
# DEBUG: 2023-05-17 18:07:08,366: Searching <ConfigDictEnv: {}> for COMET_LOGGING_FILE_LEVEL
# DEBUG: 2023-05-17 18:07:08,369: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,369: Looking up key: file_overwrite, namespace: ['comet', 'logging']
# DEBUG: 2023-05-17 18:07:08,369: Searching <ConfigOSEnv> for COMET_LOGGING_FILE_OVERWRITE
# DEBUG: 2023-05-17 18:07:08,369: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_FILE_OVERWRITE
# DEBUG: 2023-05-17 18:07:08,369: Searching <ConfigDictEnv: {}> for COMET_LOGGING_FILE_OVERWRITE
# DEBUG: 2023-05-17 18:07:08,369: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,369: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,369: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,369: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,369: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,369: Looking up key: hide_api_key, namespace: ['comet', 'logging']
# DEBUG: 2023-05-17 18:07:08,369: Searching <ConfigOSEnv> for COMET_LOGGING_HIDE_API_KEY
# DEBUG: 2023-05-17 18:07:08,369: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_HIDE_API_KEY
# DEBUG: 2023-05-17 18:07:08,374: Searching <ConfigDictEnv: {}> for COMET_LOGGING_HIDE_API_KEY
# DEBUG: 2023-05-17 18:07:08,374: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,374: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,374: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,374: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,374: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,374: Looking up key: display_summary, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,374: Searching <ConfigOSEnv> for COMET_DISPLAY_SUMMARY
# DEBUG: 2023-05-17 18:07:08,374: Searching <ConfigEnvFileEnv: None> for COMET_DISPLAY_SUMMARY
# DEBUG: 2023-05-17 18:07:08,374: Searching <ConfigDictEnv: {}> for COMET_DISPLAY_SUMMARY
# DEBUG: 2023-05-17 18:07:08,374: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,374: Looking up key: display_summary_level, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,374: Searching <ConfigOSEnv> for COMET_DISPLAY_SUMMARY_LEVEL
# DEBUG: 2023-05-17 18:07:08,374: Searching <ConfigEnvFileEnv: None> for COMET_DISPLAY_SUMMARY_LEVEL
# DEBUG: 2023-05-17 18:07:08,374: Searching <ConfigDictEnv: {}> for COMET_DISPLAY_SUMMARY_LEVEL
# DEBUG: 2023-05-17 18:07:08,374: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,374: Looking up key: code, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,374: Searching <ConfigOSEnv> for COMET_AUTO_LOG_CODE
# DEBUG: 2023-05-17 18:07:08,374: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_CODE
# DEBUG: 2023-05-17 18:07:08,374: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_CODE
# DEBUG: 2023-05-17 18:07:08,374: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,374: Looking up key: graph, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigOSEnv> for COMET_AUTO_LOG_GRAPH
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_GRAPH
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_GRAPH
# DEBUG: 2023-05-17 18:07:08,382: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,382: Looking up key: parameters, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigOSEnv> for COMET_AUTO_LOG_PARAMETERS
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_PARAMETERS
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_PARAMETERS
# DEBUG: 2023-05-17 18:07:08,382: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,382: Looking up key: metrics, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigOSEnv> for COMET_AUTO_LOG_METRICS
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_METRICS
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_METRICS
# DEBUG: 2023-05-17 18:07:08,382: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,382: Looking up key: cli_arguments, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigOSEnv> for COMET_AUTO_LOG_CLI_ARGUMENTS
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_CLI_ARGUMENTS
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_CLI_ARGUMENTS
# DEBUG: 2023-05-17 18:07:08,382: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,382: Looking up key: env_details, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,382: Searching <ConfigOSEnv> for COMET_AUTO_LOG_ENV_DETAILS
# DEBUG: 2023-05-17 18:07:08,390: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_ENV_DETAILS
# DEBUG: 2023-05-17 18:07:08,390: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_ENV_DETAILS
# DEBUG: 2023-05-17 18:07:08,390: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,390: Looking up key: git_metadata, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,390: Searching <ConfigOSEnv> for COMET_AUTO_LOG_GIT_METADATA
# DEBUG: 2023-05-17 18:07:08,390: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_GIT_METADATA
# DEBUG: 2023-05-17 18:07:08,390: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_GIT_METADATA
# DEBUG: 2023-05-17 18:07:08,390: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,390: Looking up key: git_patch, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,390: Searching <ConfigOSEnv> for COMET_AUTO_LOG_GIT_PATCH
# DEBUG: 2023-05-17 18:07:08,390: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_GIT_PATCH
# DEBUG: 2023-05-17 18:07:08,390: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_GIT_PATCH
# DEBUG: 2023-05-17 18:07:08,390: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,390: Looking up key: disable, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,390: Searching <ConfigOSEnv> for COMET_AUTO_LOG_DISABLE
# DEBUG: 2023-05-17 18:07:08,390: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_DISABLE
# DEBUG: 2023-05-17 18:07:08,390: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_DISABLE
# DEBUG: 2023-05-17 18:07:08,396: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,396: Looking up key: env_gpu, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,396: Searching <ConfigOSEnv> for COMET_AUTO_LOG_ENV_GPU
# DEBUG: 2023-05-17 18:07:08,396: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_ENV_GPU
# DEBUG: 2023-05-17 18:07:08,396: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_ENV_GPU
# DEBUG: 2023-05-17 18:07:08,396: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,396: Looking up key: env_host, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,399: Searching <ConfigOSEnv> for COMET_AUTO_LOG_ENV_HOST
# DEBUG: 2023-05-17 18:07:08,399: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_ENV_HOST
# DEBUG: 2023-05-17 18:07:08,399: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_ENV_HOST
# DEBUG: 2023-05-17 18:07:08,399: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,399: Looking up key: env_cpu, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,399: Searching <ConfigOSEnv> for COMET_AUTO_LOG_ENV_CPU
# DEBUG: 2023-05-17 18:07:08,399: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_ENV_CPU
# DEBUG: 2023-05-17 18:07:08,399: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_ENV_CPU
# DEBUG: 2023-05-17 18:07:08,399: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,399: Looking up key: co2, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,399: Searching <ConfigOSEnv> for COMET_AUTO_LOG_CO2
# DEBUG: 2023-05-17 18:07:08,399: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_CO2
# DEBUG: 2023-05-17 18:07:08,399: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_CO2
# DEBUG: 2023-05-17 18:07:08,399: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,399: Looking up key: histogram_tensorboard, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,399: Searching <ConfigOSEnv> for COMET_AUTO_LOG_HISTOGRAM_TENSORBOARD
# DEBUG: 2023-05-17 18:07:08,405: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_HISTOGRAM_TENSORBOARD
# DEBUG: 2023-05-17 18:07:08,405: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_HISTOGRAM_TENSORBOARD
# DEBUG: 2023-05-17 18:07:08,405: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,405: Looking up key: weights, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,405: Searching <ConfigOSEnv> for COMET_AUTO_LOG_WEIGHTS
# DEBUG: 2023-05-17 18:07:08,405: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_WEIGHTS
# DEBUG: 2023-05-17 18:07:08,407: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_WEIGHTS
# DEBUG: 2023-05-17 18:07:08,407: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,407: Looking up key: histogram_weights, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,407: Searching <ConfigOSEnv> for COMET_AUTO_LOG_HISTOGRAM_WEIGHTS
# DEBUG: 2023-05-17 18:07:08,409: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_HISTOGRAM_WEIGHTS
# DEBUG: 2023-05-17 18:07:08,409: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_HISTOGRAM_WEIGHTS
# DEBUG: 2023-05-17 18:07:08,409: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,409: Looking up key: weights, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,409: Searching <ConfigOSEnv> for COMET_AUTO_LOG_WEIGHTS
# DEBUG: 2023-05-17 18:07:08,409: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_WEIGHTS
# DEBUG: 2023-05-17 18:07:08,409: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_WEIGHTS
# DEBUG: 2023-05-17 18:07:08,409: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,409: Looking up key: histogram_gradients, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,409: Searching <ConfigOSEnv> for COMET_AUTO_LOG_HISTOGRAM_GRADIENTS
# DEBUG: 2023-05-17 18:07:08,409: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_HISTOGRAM_GRADIENTS
# DEBUG: 2023-05-17 18:07:08,409: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_HISTOGRAM_GRADIENTS
# DEBUG: 2023-05-17 18:07:08,409: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,409: Looking up key: histogram_activations, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,409: Searching <ConfigOSEnv> for COMET_AUTO_LOG_HISTOGRAM_ACTIVATIONS
# DEBUG: 2023-05-17 18:07:08,409: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_HISTOGRAM_ACTIVATIONS
# DEBUG: 2023-05-17 18:07:08,416: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_HISTOGRAM_ACTIVATIONS
# DEBUG: 2023-05-17 18:07:08,416: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,416: Looking up key: metric_step_rate, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,416: Searching <ConfigOSEnv> for COMET_AUTO_LOG_METRIC_STEP_RATE
# DEBUG: 2023-05-17 18:07:08,416: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_METRIC_STEP_RATE
# DEBUG: 2023-05-17 18:07:08,416: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_METRIC_STEP_RATE
# DEBUG: 2023-05-17 18:07:08,416: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,416: Looking up key: histogram_epoch_rate, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,416: Searching <ConfigOSEnv> for COMET_AUTO_LOG_HISTOGRAM_EPOCH_RATE
# DEBUG: 2023-05-17 18:07:08,416: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_HISTOGRAM_EPOCH_RATE
# DEBUG: 2023-05-17 18:07:08,416: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_HISTOGRAM_EPOCH_RATE
# DEBUG: 2023-05-17 18:07:08,416: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,416: Looking up key: output_logger, namespace: ['comet', 'auto_log']
# DEBUG: 2023-05-17 18:07:08,416: Searching <ConfigOSEnv> for COMET_AUTO_LOG_OUTPUT_LOGGER
# DEBUG: 2023-05-17 18:07:08,416: Searching <ConfigEnvFileEnv: None> for COMET_AUTO_LOG_OUTPUT_LOGGER
# DEBUG: 2023-05-17 18:07:08,416: Searching <ConfigDictEnv: {}> for COMET_AUTO_LOG_OUTPUT_LOGGER
# DEBUG: 2023-05-17 18:07:08,416: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,416: Looking up key: others_ignore, namespace: ['comet', 'logging']
# DEBUG: 2023-05-17 18:07:08,416: Searching <ConfigOSEnv> for COMET_LOGGING_OTHERS_IGNORE
# DEBUG: 2023-05-17 18:07:08,423: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_OTHERS_IGNORE
# DEBUG: 2023-05-17 18:07:08,423: Searching <ConfigDictEnv: {}> for COMET_LOGGING_OTHERS_IGNORE
# DEBUG: 2023-05-17 18:07:08,423: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,423: Looking up key: metrics_ignore, namespace: ['comet', 'logging']
# DEBUG: 2023-05-17 18:07:08,424: Searching <ConfigOSEnv> for COMET_LOGGING_METRICS_IGNORE
# DEBUG: 2023-05-17 18:07:08,424: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_METRICS_IGNORE
# DEBUG: 2023-05-17 18:07:08,424: Searching <ConfigDictEnv: {}> for COMET_LOGGING_METRICS_IGNORE
# DEBUG: 2023-05-17 18:07:08,424: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,424: Looking up key: parameters_ignore, namespace: ['comet', 'logging']
# DEBUG: 2023-05-17 18:07:08,424: Searching <ConfigOSEnv> for COMET_LOGGING_PARAMETERS_IGNORE
# DEBUG: 2023-05-17 18:07:08,426: Searching <ConfigEnvFileEnv: None> for COMET_LOGGING_PARAMETERS_IGNORE
# DEBUG: 2023-05-17 18:07:08,427: Searching <ConfigDictEnv: {}> for COMET_LOGGING_PARAMETERS_IGNORE
# DEBUG: 2023-05-17 18:07:08,427: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,427: Looking up key: experiment_key, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,427: Searching <ConfigOSEnv> for COMET_EXPERIMENT_KEY
# DEBUG: 2023-05-17 18:07:08,427: Searching <ConfigEnvFileEnv: None> for COMET_EXPERIMENT_KEY
# DEBUG: 2023-05-17 18:07:08,427: Searching <ConfigDictEnv: {}> for COMET_EXPERIMENT_KEY
# DEBUG: 2023-05-17 18:07:08,427: Found nothing--returning NO_VALUE
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# DEBUG: 2023-05-17 18:07:08,430: Looking up key: check_tls_certificate, namespace: ['comet', 'internal']
# DEBUG: 2023-05-17 18:07:08,430: Searching <ConfigOSEnv> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# DEBUG: 2023-05-17 18:07:08,430: Searching <ConfigEnvFileEnv: None> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# DEBUG: 2023-05-17 18:07:08,430: Searching <ConfigDictEnv: {}> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# DEBUG: 2023-05-17 18:07:08,430: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,432: Looking up key: url_override, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,432: Searching <ConfigOSEnv> for COMET_URL_OVERRIDE
# DEBUG: 2023-05-17 18:07:08,432: Searching <ConfigEnvFileEnv: None> for COMET_URL_OVERRIDE
# DEBUG: 2023-05-17 18:07:08,432: Searching <ConfigDictEnv: {}> for COMET_URL_OVERRIDE
# DEBUG: 2023-05-17 18:07:08,432: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,432: Looking up key: http, namespace: ['comet', 'timeout']
# DEBUG: 2023-05-17 18:07:08,432: Searching <ConfigOSEnv> for COMET_TIMEOUT_HTTP
# DEBUG: 2023-05-17 18:07:08,432: Searching <ConfigEnvFileEnv: None> for COMET_TIMEOUT_HTTP
# DEBUG: 2023-05-17 18:07:08,432: Searching <ConfigDictEnv: {}> for COMET_TIMEOUT_HTTP
# DEBUG: 2023-05-17 18:07:08,432: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,432: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,432: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,432: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,432: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,442: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,442: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,442: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,442: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,442: Looking up key: name, namespace: ['comet', 'allow_header']
# DEBUG: 2023-05-17 18:07:08,442: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-05-17 18:07:08,442: Searching <ConfigEnvFileEnv: None> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-05-17 18:07:08,442: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-05-17 18:07:08,442: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,442: Looking up key: value, namespace: ['comet', 'allow_header']
# DEBUG: 2023-05-17 18:07:08,442: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_VALUE
# DEBUG: 2023-05-17 18:07:08,442: Searching <ConfigEnvFileEnv: None> for COMET_ALLOW_HEADER_VALUE
# DEBUG: 2023-05-17 18:07:08,442: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_VALUE
# DEBUG: 2023-05-17 18:07:08,442: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,449: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,449: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,449: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,449: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,455: Looking up key: name, namespace: ['comet', 'allow_header']
# DEBUG: 2023-05-17 18:07:08,455: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-05-17 18:07:08,455: Searching <ConfigEnvFileEnv: None> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-05-17 18:07:08,456: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-05-17 18:07:08,456: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,457: Looking up key: value, namespace: ['comet', 'allow_header']
# DEBUG: 2023-05-17 18:07:08,457: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_VALUE
# DEBUG: 2023-05-17 18:07:08,457: Searching <ConfigEnvFileEnv: None> for COMET_ALLOW_HEADER_VALUE
# DEBUG: 2023-05-17 18:07:08,457: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_VALUE
# DEBUG: 2023-05-17 18:07:08,457: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,457: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,457: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,457: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,457: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,457: Looking up key: url_override, namespace: ['comet']
# DEBUG: 2023-05-17 18:07:08,457: Searching <ConfigOSEnv> for COMET_URL_OVERRIDE
# DEBUG: 2023-05-17 18:07:08,457: Searching <ConfigEnvFileEnv: None> for COMET_URL_OVERRIDE
# DEBUG: 2023-05-17 18:07:08,457: Searching <ConfigDictEnv: {}> for COMET_URL_OVERRIDE
# DEBUG: 2023-05-17 18:07:08,457: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,457: Looking up key: api, namespace: ['comet', 'timeout']
# DEBUG: 2023-05-17 18:07:08,463: Searching <ConfigOSEnv> for COMET_TIMEOUT_API
# DEBUG: 2023-05-17 18:07:08,463: Searching <ConfigEnvFileEnv: None> for COMET_TIMEOUT_API
# DEBUG: 2023-05-17 18:07:08,463: Searching <ConfigDictEnv: {}> for COMET_TIMEOUT_API
# DEBUG: 2023-05-17 18:07:08,463: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,465: Looking up key: check_tls_certificate, namespace: ['comet', 'internal']
# DEBUG: 2023-05-17 18:07:08,465: Searching <ConfigOSEnv> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# DEBUG: 2023-05-17 18:07:08,465: Searching <ConfigEnvFileEnv: None> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# DEBUG: 2023-05-17 18:07:08,467: Searching <ConfigDictEnv: {}> for COMET_INTERNAL_CHECK_TLS_CERTIFICATE
# DEBUG: 2023-05-17 18:07:08,467: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:07:08,471: No INI file found: []
# DEBUG: 2023-05-17 18:07:08,471: No INI file found: ['./.comet.config']
# DEBUG: 2023-05-17 18:07:08,473: No INI file found: ['/content/drive/MyDrive/.comet.config']
# DEBUG: 2023-05-17 18:07:08,473: No INI file found: ['~/.comet.config']
# DEBUG: 2023-05-17 18:07:08,473: Looking up key: name, namespace: ['comet', 'allow_header']
# DEBUG: 2023-05-17 18:07:08,473: Searching <ConfigOSEnv> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-05-17 18:07:08,473: Searching <ConfigEnvFileEnv: None> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-05-17 18:07:08,473: Searching <ConfigDictEnv: {}> for COMET_ALLOW_HEADER_NAME
# DEBUG: 2023-05-17 18:07:08,477: Found nothing--returning NO_VALUE
# ...
# DEBUG: 2023-05-17 18:30:24,218: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:30:24,221: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:30:24,221: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:30:30,708: https://www.comet.com:443 "GET /clientlib/health/ping HTTP/1.1" 200 67
# DEBUG: 2023-05-17 18:30:33,089: https://www.comet.com:443 "POST /clientlib/batch/logger/experiment/metric HTTP/1.1" 200 55
# DEBUG: 2023-05-17 18:30:34,397: https://www.comet.com:443 "POST /clientlib/status-report/update HTTP/1.1" 200 159
# DEBUG: 2023-05-17 18:30:34,399: Looking up key: parameters_interval, namespace: ['comet', 'message_batch']
# DEBUG: 2023-05-17 18:30:34,399: Searching <ConfigOSEnv> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:30:34,399: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:30:34,399: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:30:34,404: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:30:44,591: https://www.comet.com:443 "POST /clientlib/status-report/update HTTP/1.1" 200 159
# DEBUG: 2023-05-17 18:30:44,591: Looking up key: parameters_interval, namespace: ['comet', 'message_batch']
# DEBUG: 2023-05-17 18:30:44,591: Searching <ConfigOSEnv> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:30:44,591: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:30:44,601: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:30:44,603: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:30:45,884: https://www.comet.com:443 "GET /clientlib/health/ping HTTP/1.1" 200 67
# DEBUG: 2023-05-17 18:30:54,820: https://www.comet.com:443 "POST /clientlib/status-report/update HTTP/1.1" 200 159
# DEBUG: 2023-05-17 18:30:54,820: Looking up key: parameters_interval, namespace: ['comet', 'message_batch']
# DEBUG: 2023-05-17 18:30:54,828: Searching <ConfigOSEnv> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:30:54,828: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:30:54,828: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:30:54,828: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:31:01,492: https://www.comet.com:443 "GET /clientlib/health/ping HTTP/1.1" 200 67
# DEBUG: 2023-05-17 18:31:05,080: https://www.comet.com:443 "POST /clientlib/status-report/update HTTP/1.1" 200 159
# DEBUG: 2023-05-17 18:31:05,080: Looking up key: parameters_interval, namespace: ['comet', 'message_batch']
# DEBUG: 2023-05-17 18:31:05,080: Searching <ConfigOSEnv> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:05,080: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:05,080: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:05,080: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:31:15,335: https://www.comet.com:443 "POST /clientlib/status-report/update HTTP/1.1" 200 159
# DEBUG: 2023-05-17 18:31:15,335: Looking up key: parameters_interval, namespace: ['comet', 'message_batch']
# DEBUG: 2023-05-17 18:31:15,335: Searching <ConfigOSEnv> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:15,335: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:15,346: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:15,346: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:31:16,825: https://www.comet.com:443 "GET /clientlib/health/ping HTTP/1.1" 200 67
# DEBUG: 2023-05-17 18:31:23,065: Looking up key: distributed_node_identifier, namespace: ['comet']
# DEBUG: 2023-05-17 18:31:23,068: Searching <ConfigOSEnv> for COMET_DISTRIBUTED_NODE_IDENTIFIER
# DEBUG: 2023-05-17 18:31:23,068: Searching <ConfigEnvFileEnv: None> for COMET_DISTRIBUTED_NODE_IDENTIFIER
# DEBUG: 2023-05-17 18:31:23,069: Searching <ConfigDictEnv: {'COMET_OVERRIDE_FEATURE_ACADEMIC': True, 'COMET_OVERRIDE_FEATURE_ARTIFACTS': True, 'COMET_OVERRIDE_FEATURE_ASSET-STORAGE': True, 'COMET_OVERRIDE_FEATURE_BILLING-REDESIGN': True, 'COMET_OVERRIDE_FEATURE_BREAK-DOWN-BY': False, 'COMET_OVERRIDE_FEATURE_CLOSEST-HOVER-MODE': True, 'COMET_OVERRIDE_FEATURE_CONFUSION-MATRIX': True, 'COMET_OVERRIDE_FEATURE_CUSTOM-CHARTS': True, 'COMET_OVERRIDE_FEATURE_DASHBOARD-CHARTS': True, 'COMET_OVERRIDE_FEATURE_DASHBOARD_TEMPLATES': True, 'COMET_OVERRIDE_FEATURE_DATA-PANEL': True, 'COMET_OVERRIDE_FEATURE_DBS-MODEL-PRODUCTION-MONITORING': False, 'COMET_OVERRIDE_FEATURE_DISABLE-TABLE-ROW-EXPAND': False, 'COMET_OVERRIDE_FEATURE_DOWNLOAD-ASSET-DIRECTORY': True, 'COMET_OVERRIDE_FEATURE_GIT-REPRODUCE': True, 'COMET_OVERRIDE_FEATURE_GROUP-BY-ENDPOINT': True, 'COMET_OVERRIDE_FEATURE_GROUPING': True, 'COMET_OVERRIDE_FEATURE_MODEL-APPROVAL-PROCESS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-ACCURACY-METRICS-TAB': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-ALERTS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-CUSTOM-TRANSFORMATIONS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-DEBUGGER': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-INTERNAL': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-MODELS-PIPELINE': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-SEGMENTS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-SEGMENTS-NEW-PANEL': False, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-CARD-DETAILS-V2': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-STAGES-TO-TAGS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-STREAMLINE': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-WEBHOOKS': True, 'COMET_OVERRIDE_FEATURE_NEW-ONBOARDING': True, 'COMET_OVERRIDE_FEATURE_NEW-WORDPRESS-SITE': True, 'COMET_OVERRIDE_FEATURE_OLD_TEAMS': True, 'COMET_OVERRIDE_FEATURE_PAYMENTS': True, 'COMET_OVERRIDE_FEATURE_PLOTLY-CHARTS': True, 'COMET_OVERRIDE_FEATURE_PUBLIC-PANELS': True, 'COMET_OVERRIDE_FEATURE_PYTHON-PANELS': True, 'COMET_OVERRIDE_FEATURE_QUERY-FILTER': True, 'COMET_OVERRIDE_FEATURE_QUERY-URL-PARSER': False, 'COMET_OVERRIDE_FEATURE_REACT_HEADER_ICON_OVERRIDE': False, 'COMET_OVERRIDE_FEATURE_REPRODUCE-NOTEBOOKS': True, 'COMET_OVERRIDE_FEATURE_SDK_ANNOUNCEMENT': True, 'COMET_OVERRIDE_FEATURE_SDK_GIT_PATCH': True, 'COMET_OVERRIDE_FEATURE_SDK_GPU_MONITOR': True, 'COMET_OVERRIDE_FEATURE_SDK_HTTP_LOGGING': False, 'COMET_OVERRIDE_FEATURE_SDK_LOG_ENV_VARIABLES': False, 'COMET_OVERRIDE_FEATURE_SDK_METRICS_HTTP_BATCHING': False, 'COMET_OVERRIDE_FEATURE_SDK_USE_HTTP_MESSAGES': True, 'COMET_OVERRIDE_FEATURE_SERVICE-ACCOUNTS': True, 'COMET_OVERRIDE_FEATURE_SYSTEM-METRICS': True, 'COMET_OVERRIDE_FEATURE_SYSTEM-METRICS-GPU': True, 'COMET_OVERRIDE_FEATURE_TAGS': True, 'COMET_OVERRIDE_FEATURE_TEST-FT-ENV-CHECK': True, 'COMET_OVERRIDE_FEATURE_TEXT-TAB': True, 'COMET_OVERRIDE_FEATURE_USE_HTTP_MESSAGES': True}> for COMET_DISTRIBUTED_NODE_IDENTIFIER
# DEBUG: 2023-05-17 18:31:23,069: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:31:23,265: https://www.comet.com:443 "POST /clientlib/batch/logger/experiment/metric HTTP/1.1" 200 55
# DEBUG: 2023-05-17 18:31:25,533: https://www.comet.com:443 "POST /clientlib/status-report/update HTTP/1.1" 200 159
# DEBUG: 2023-05-17 18:31:25,533: Looking up key: parameters_interval, namespace: ['comet', 'message_batch']
# DEBUG: 2023-05-17 18:31:25,538: Searching <ConfigOSEnv> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:25,538: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:25,539: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:25,539: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:31:32,045: https://www.comet.com:443 "GET /clientlib/health/ping HTTP/1.1" 200 67
# DEBUG: 2023-05-17 18:31:33,505: https://www.comet.com:443 "POST /clientlib/batch/logger/experiment/metric HTTP/1.1" 200 55
# DEBUG: 2023-05-17 18:31:35,717: https://www.comet.com:443 "POST /clientlib/status-report/update HTTP/1.1" 200 159
# DEBUG: 2023-05-17 18:31:35,725: Looking up key: parameters_interval, namespace: ['comet', 'message_batch']
# DEBUG: 2023-05-17 18:31:35,725: Searching <ConfigOSEnv> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:35,725: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:35,725: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:35,725: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:31:45,961: https://www.comet.com:443 "POST /clientlib/status-report/update HTTP/1.1" 200 159
# DEBUG: 2023-05-17 18:31:45,970: Looking up key: parameters_interval, namespace: ['comet', 'message_batch']
# DEBUG: 2023-05-17 18:31:45,970: Searching <ConfigOSEnv> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:45,970: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:45,970: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:45,970: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:31:47,277: https://www.comet.com:443 "GET /clientlib/health/ping HTTP/1.1" 200 67
# DEBUG: 2023-05-17 18:31:56,174: https://www.comet.com:443 "POST /clientlib/status-report/update HTTP/1.1" 200 159
# DEBUG: 2023-05-17 18:31:56,180: Looking up key: parameters_interval, namespace: ['comet', 'message_batch']
# DEBUG: 2023-05-17 18:31:56,180: Searching <ConfigOSEnv> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:56,180: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:56,183: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:31:56,183: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:32:02,592: https://www.comet.com:443 "GET /clientlib/health/ping HTTP/1.1" 200 67
# DEBUG: 2023-05-17 18:32:06,352: https://www.comet.com:443 "POST /clientlib/status-report/update HTTP/1.1" 200 159
# DEBUG: 2023-05-17 18:32:06,352: Looking up key: parameters_interval, namespace: ['comet', 'message_batch']
# DEBUG: 2023-05-17 18:32:06,352: Searching <ConfigOSEnv> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:32:06,352: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:32:06,352: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:32:06,352: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:32:16,566: https://www.comet.com:443 "POST /clientlib/status-report/update HTTP/1.1" 200 159
# DEBUG: 2023-05-17 18:32:16,566: Looking up key: parameters_interval, namespace: ['comet', 'message_batch']
# DEBUG: 2023-05-17 18:32:16,566: Searching <ConfigOSEnv> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:32:16,566: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:32:16,566: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:32:16,582: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:32:17,755: https://www.comet.com:443 "GET /clientlib/health/ping HTTP/1.1" 200 67
# DEBUG: 2023-05-17 18:32:23,424: Looking up key: distributed_node_identifier, namespace: ['comet']
# DEBUG: 2023-05-17 18:32:23,425: Searching <ConfigOSEnv> for COMET_DISTRIBUTED_NODE_IDENTIFIER
# DEBUG: 2023-05-17 18:32:23,427: Searching <ConfigEnvFileEnv: None> for COMET_DISTRIBUTED_NODE_IDENTIFIER
# DEBUG: 2023-05-17 18:32:23,427: Searching <ConfigDictEnv: {'COMET_OVERRIDE_FEATURE_ACADEMIC': True, 'COMET_OVERRIDE_FEATURE_ARTIFACTS': True, 'COMET_OVERRIDE_FEATURE_ASSET-STORAGE': True, 'COMET_OVERRIDE_FEATURE_BILLING-REDESIGN': True, 'COMET_OVERRIDE_FEATURE_BREAK-DOWN-BY': False, 'COMET_OVERRIDE_FEATURE_CLOSEST-HOVER-MODE': True, 'COMET_OVERRIDE_FEATURE_CONFUSION-MATRIX': True, 'COMET_OVERRIDE_FEATURE_CUSTOM-CHARTS': True, 'COMET_OVERRIDE_FEATURE_DASHBOARD-CHARTS': True, 'COMET_OVERRIDE_FEATURE_DASHBOARD_TEMPLATES': True, 'COMET_OVERRIDE_FEATURE_DATA-PANEL': True, 'COMET_OVERRIDE_FEATURE_DBS-MODEL-PRODUCTION-MONITORING': False, 'COMET_OVERRIDE_FEATURE_DISABLE-TABLE-ROW-EXPAND': False, 'COMET_OVERRIDE_FEATURE_DOWNLOAD-ASSET-DIRECTORY': True, 'COMET_OVERRIDE_FEATURE_GIT-REPRODUCE': True, 'COMET_OVERRIDE_FEATURE_GROUP-BY-ENDPOINT': True, 'COMET_OVERRIDE_FEATURE_GROUPING': True, 'COMET_OVERRIDE_FEATURE_MODEL-APPROVAL-PROCESS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-ACCURACY-METRICS-TAB': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-ALERTS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-CUSTOM-TRANSFORMATIONS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-DEBUGGER': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-INTERNAL': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-MODELS-PIPELINE': False, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-SEGMENTS': True, 'COMET_OVERRIDE_FEATURE_MODEL-PRODUCTION-MONITORING-SEGMENTS-NEW-PANEL': False, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-CARD-DETAILS-V2': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-STAGES-TO-TAGS': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-STREAMLINE': True, 'COMET_OVERRIDE_FEATURE_MODEL-REGISTRY-WEBHOOKS': True, 'COMET_OVERRIDE_FEATURE_NEW-ONBOARDING': True, 'COMET_OVERRIDE_FEATURE_NEW-WORDPRESS-SITE': True, 'COMET_OVERRIDE_FEATURE_OLD_TEAMS': True, 'COMET_OVERRIDE_FEATURE_PAYMENTS': True, 'COMET_OVERRIDE_FEATURE_PLOTLY-CHARTS': True, 'COMET_OVERRIDE_FEATURE_PUBLIC-PANELS': True, 'COMET_OVERRIDE_FEATURE_PYTHON-PANELS': True, 'COMET_OVERRIDE_FEATURE_QUERY-FILTER': True, 'COMET_OVERRIDE_FEATURE_QUERY-URL-PARSER': False, 'COMET_OVERRIDE_FEATURE_REACT_HEADER_ICON_OVERRIDE': False, 'COMET_OVERRIDE_FEATURE_REPRODUCE-NOTEBOOKS': True, 'COMET_OVERRIDE_FEATURE_SDK_ANNOUNCEMENT': True, 'COMET_OVERRIDE_FEATURE_SDK_GIT_PATCH': True, 'COMET_OVERRIDE_FEATURE_SDK_GPU_MONITOR': True, 'COMET_OVERRIDE_FEATURE_SDK_HTTP_LOGGING': False, 'COMET_OVERRIDE_FEATURE_SDK_LOG_ENV_VARIABLES': False, 'COMET_OVERRIDE_FEATURE_SDK_METRICS_HTTP_BATCHING': False, 'COMET_OVERRIDE_FEATURE_SDK_USE_HTTP_MESSAGES': True, 'COMET_OVERRIDE_FEATURE_SERVICE-ACCOUNTS': True, 'COMET_OVERRIDE_FEATURE_SYSTEM-METRICS': True, 'COMET_OVERRIDE_FEATURE_SYSTEM-METRICS-GPU': True, 'COMET_OVERRIDE_FEATURE_TAGS': True, 'COMET_OVERRIDE_FEATURE_TEST-FT-ENV-CHECK': True, 'COMET_OVERRIDE_FEATURE_TEXT-TAB': True, 'COMET_OVERRIDE_FEATURE_USE_HTTP_MESSAGES': True}> for COMET_DISTRIBUTED_NODE_IDENTIFIER
# DEBUG: 2023-05-17 18:32:23,427: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:32:23,608: https://www.comet.com:443 "POST /clientlib/batch/logger/experiment/metric HTTP/1.1" 200 55
# DEBUG: 2023-05-17 18:32:26,761: https://www.comet.com:443 "POST /clientlib/status-report/update HTTP/1.1" 200 159
# DEBUG: 2023-05-17 18:32:26,764: Looking up key: parameters_interval, namespace: ['comet', 'message_batch']
# DEBUG: 2023-05-17 18:32:26,764: Searching <ConfigOSEnv> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:32:26,764: Searching <ConfigEnvFileEnv: None> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:32:26,764: Searching <ConfigDictEnv: {}> for COMET_MESSAGE_BATCH_PARAMETERS_INTERVAL
# DEBUG: 2023-05-17 18:32:26,764: Found nothing--returning NO_VALUE
# DEBUG: 2023-05-17 18:32:32,915: https://www.comet.com:443 "GET /clientlib/health/ping HTTP/1.1" 200 67
# DEBUG: 2023-05-17 18:32:33,773: https://www.comet.com:443 "POST /clientlib/batch/logger/experiment/metric HTTP/1.1" 200 55
